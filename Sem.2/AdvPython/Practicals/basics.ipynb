# %%
a = input("Daal na yaaarrrrrrrrrrrrrrr:")

for i in range(1, int(a)+1):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
a = 5
b = 8
c = 3

if a > b:
    if a > c:
        print(a)
    else:
        print(c)
elif c > b:
    print(c)
else:
    print(b)
# Out:
# 8

# %%
a = [1,2, 54, 7, 54]
b = (346, 67, 978)

list(b), tuple(a)
# Out:
# ([346, 67, 978], (1, 2, 54, 7, 54))

# %%
data = [
    {"Name": "Aditya", "Marks": -50},
    {"Name": "Lovesh", "Marks": 100},
]

# %%
import pandas as pd

df = pd.DataFrame(data)
df
# Out:
#       Name  Marks
# 0  Aditiya    -50
# 1   Lovesh    100

# %%
df.to_csv("data/marks.csv")

# %%
df_read = pd.read_csv("data/marks.csv", index_col=[0, 1])
df_read
# Out:
#            Marks
#   Name
# 0 Aditiya    -50
# 1 Lovesh     100

# %%
df_read.loc[0:1]
# Out:
#            Marks
#   Name
# 0 Aditiya    -50
# 1 Lovesh     100

# %%
df_read.index
